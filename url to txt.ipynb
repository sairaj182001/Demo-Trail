# %%
import urllib

# %%
link = "https://doi.org/10.24434/j.scoms.2022.03.3340"
f = urllib.request.urlopen(link)
myfile = f.read()
print(myfile)
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US" xml:lang="en-US">\n<head>\n\t<meta charset="utf-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\n\t<title>\n\t\tThe value of face-to-face communication in the digital world: What people miss about in-person interactions when those are limited\n\t\t\t\t\t\t\t| Studies in Communication Sciences\n\t\t\t</title>\n\n\t\n<meta name="generator" content="Open Journal Systems 3.3.0.13">\n<link rel="schema.DC" href="http://purl.org/dc/elements/1.1/" />\n<meta name="DC.Creator.PersonalName" content="Jonathan Gruber"/>\n<meta name="DC.Creator.PersonalName" content="Eszter Hargittai"/>\n<meta name="DC.Creator.PersonalName" content="Minh Hao Nguyen "/>\n<meta name="DC.Date.created" scheme="ISO8601" content="2022-12-28"/>\n<meta name="DC.Date.dateSubmitted" scheme="ISO8601" content="2022-01-12"/>\n<meta name="DC.Date.issued" scheme="ISO8601" content="2022-12-28"/>\n<meta name="DC.Date.modified" scheme="ISO8601" content="2022-12-28"
# ...
